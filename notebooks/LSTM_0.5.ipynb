# 5  -0.488844 -0.392214  1.226224 -0.434421  5.175496e-02        -0.455369
# 6  -0.488844 -0.392214  1.105901 -0.430141  4.194376e-02        -0.440763
# 7  -0.488844 -0.392214  1.094388 -0.438688  5.086110e-02        -0.434161
# 8  -0.488844 -0.392214  0.524578 -0.446945  3.473578e-02        -0.395872
# 9  -0.488844 -0.392214  1.059071 -0.435083  4.540177e-02        -0.374060
# 10 -0.488844 -0.374060  0.537175 -0.437769  3.938216e-02        -0.386190
# 11 -0.488844 -0.374060  0.694867 -0.431332  4.211088e-02        -0.407645
# 12 -0.488844 -0.374060  0.678422 -0.430040  4.022912e-02        -0.372739
# 13 -0.488844 -0.372739  1.070733 -0.422946  5.375820e-02        -0.338356
# 14 -0.488844 -0.338356  0.366604 -0.428210  4.229176e-02        -0.286452
# 15 -0.488844 -0.286452  0.141871 -0.428053  4.560784e-02        -0.270938
# 16 -0.488844 -0.270938 -0.799264 -0.440190  5.791263e-02        -0.272369
# 17 -0.488844 -0.270938  0.068772 -0.420370  5.378938e-02        -0.345508
# 18 -0.488844 -0.270938 -0.793014 -0.434458  6.371012e-02        -0.380166
# 19 -0.488844 -0.270938  0.137336 -0.414762  5.476862e-02        -0.342840

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
data_set_scaled = sc.fit_transform(data_set)
print(data_set_scaled)
# Out:
# [[0.00000000e+00 0.00000000e+00 4.55565481e-01 ... 1.70613104e-01
#   0.00000000e+00 4.74273521e-01]
#  [1.85219485e-04 1.85215206e-04 4.74273521e-01 ... 2.77166544e-01
#   1.62614862e-02 4.79390636e-01]
#  [3.70438970e-04 3.70446878e-04 4.79390636e-01 ... 3.04974606e-01
#   1.94226630e-02 4.36270606e-01]
#  ...
#  [9.99629561e-01 9.99629537e-01 7.10060562e-01 ... 8.48205810e-01
#   3.37937265e-01 7.37242386e-01]
#  [9.99814781e-01 9.99814768e-01 7.37242386e-01 ... 8.48467712e-01
#   3.37967716e-01 7.78601945e-01]
#  [1.00000000e+00 1.00000000e+00 7.78601945e-01 ... 8.48651553e-01
#   3.38012788e-01 7.64236424e-01]]

# %%
# multiple feature from data provided to the model
X = []

backcandles = 10
print(data_set_scaled.shape[0])
for j in range(8):#data_set_scaled[0].size):#2 columns are target not X
    X.append([])
    for i in range(backcandles, data_set_scaled.shape[0]):#backcandles+2
        X[j].append(data_set_scaled[i-backcandles:i, j])

#move axis from 0 to position 2
X=np.moveaxis(X, [0], [2])

X, yi =np.array(X), np.array(data_set_scaled[backcandles:,-1])
y=np.reshape(yi,(len(yi),1))
# Out:
# 5400

# %%
splitlimit = int(len(X)*0.5)
print(splitlimit)
X_train, X_test = X[:splitlimit], X[splitlimit:]
y_train, y_test = y[:splitlimit], y[splitlimit:]
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
print(y_train)
# Out:
# 2695
# (2695, 10, 8)
# (2695, 10, 8)
# (2695, 1)
# (2695, 1)
# [[0.48453124]
#  [0.46622226]
#  [0.4960096 ]
#  ...
#  [0.60868035]
#  [0.60755364]
#  [0.61781138]]

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed

import tensorflow as tf
import keras
from keras import optimizers
from keras.callbacks import History
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
import numpy as np
#tf.random.set_seed(20)
np.random.seed(10)

lstm_input = Input(shape=(backcandles, 8), name='lstm_input')
inputs = LSTM(150, name='first_layer')(lstm_input)
inputs = Dense(1, name='dense_layer')(inputs)
output = Activation('linear', name='output')(inputs)
model = Model(inputs=lstm_input, outputs=output)
adam = optimizers.Adam()
model.compile(optimizer=adam, loss='mse')
model.fit(x=X_train, y=y_train, batch_size=15, epochs=30, shuffle=True, validation_split = 0.1)
# Out:
# Epoch 1/30
# 162/162 [==============================] - 3s 8ms/step - loss: 0.0119 - val_loss: 0.0044
# Epoch 2/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 3/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 4/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 5/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 6/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 7/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 8/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 9/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 10/30
# 162/162 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 11/30
# 162/162 [==============================] - 1s 8ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 12/30
# 162/162 [==============================] - 1s 7ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 13/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 14/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 15/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 16/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 17/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 18/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 19/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 20/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 21/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 22/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 23/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 24/30
# 162/162 [==============================] - 1s 5ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 25/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 26/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 27/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 28/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 29/30
# 162/162 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 30/30
# 162/162 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 0.0023

# %%
y_pred = model.predict(X_test)
#y_pred=np.where(y_pred > 0.43, 1,0)
for i in range(10):
    print(y_pred[i], y_test[i])
# Out:
# 85/85 [==============================] - 1s 4ms/step
# [0.5954457] [0.63710625]
# [0.6126634] [0.64912447]
# [0.62869227] [0.64569739]
# [0.6332313] [0.63926577]
# [0.62292975] [0.61137975]
# [0.62025756] [0.59586404]
# [0.5813693] [0.5751608]
# [0.5855004] [0.56509085]
# [0.55346465] [0.55025586]
# [0.5584809] [0.54408244]

# %%
plt.figure(figsize=(16,8))
plt.plot([i + len(y_train) for i in range(len(y_test))], y_test, color = 'black', label = 'Test')
plt.plot([i + len(y_train) for i in range(len(y_pred))], y_pred, color = 'green', label = 'pred')
plt.plot([i for i in range(len(y_train))], y_train, color = 'red', label = 'train')
# plt.plot(y_pred, color = 'green', label = 'pred')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot([i + len(y_train) for i in range(len(y_test))], y_test, color = 'black', label = 'Test')
plt.plot([i + len(y_train) for i in range(len(y_pred))], y_pred, color = 'green', label = 'pred')
# plt.plot([i for i in range(len(y_train))], y_train, color = 'red', label = 'train')
# plt.plot(y_pred, color = 'green', label = 'pred')
plt.legend()
plt.show()
